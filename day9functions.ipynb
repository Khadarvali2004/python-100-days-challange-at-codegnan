# %%
#functions defination
def even_or_odd(x):
    if x%2==0:
        return 'even'
    else:
        return 'odd'
#function calling
res=even_or_odd(10)
print(res)
# Out:
# even

# %%
#functions defination
def even_or_odd(x):
    if x%2==0:
        print('even')
    else:
        print('odd')
#function calling
res=even_or_odd(10)
print(res)
# Out:
# even
# None

# %%
#sum of list of numbers
def sum_of_list(numbers):
    total=0
    for num in numbers:
        total+=num
    return total
my_list=[1,2,3,8]
res=sum_of_list(my_list)
print(res)
# Out:
# 14

# %%
#sum of two numbers 
def sum_of_numbers(x,y):
    sum_result=x+y
    return sum_result
n1=int(input())
n2=int(input())
res=sum_of_numbers(n1,n2)
print(res)
# Out:
#  10
#  03
# 13

# %%
#sum of three numbers 
def sum_of_numbers(x,y,z):
    sum_result=x+y+z
    return sum_result
n1=100
n2=200
n3=300
res=sum_of_numbers(n1,n2,n3)
print(res)
# Out:
# 600
